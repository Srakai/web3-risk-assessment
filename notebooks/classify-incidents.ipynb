# %%
# !pip install -q pydantic google-genai
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import json
from pydantic import BaseModel, Field
from typing import Literal, Optional, List, Tuple
from google import genai


client = genai.Client(
    api_key=os.environ.get("GEMINI_API_KEY"),
)

incidents_file = "../data/incidents-dataset-20250906.json"

# %%
class Incident(BaseModel):
    """Represents a single security incident."""

    proto: Literal["eth", "sol", "bnb", "btc", "other"] = Field(
        description="The blockchain protocol involved, like 'eth', 'sol', or 'btc'."
    )
    type: str = Field(
        description="The general category of the incident. Either: scam, exploit, rugpull, or other (name)."
    )
    exploit_type: str = Field(
        description="The specific type of exploit (e.g., 'Re-entrancy', 'Price Oracle Manipulation', 'Access Control')."
    )
    total_value_extracted: str = Field(
        description="The total value extracted in USD or equivalent (e.g., '$3M', '5 BTC'). If multiple currencies, list them separated by commas."
    )
    hack_date: str = Field(description="The date of the hack in YYYY-MM-DD format.")
    hacked_app_name: str = Field(
        description="The name of the hacked application or protocol."
    )
    hacked_app_website: Optional[str] = Field(
        default=None, description="The website of the hacked application, if known."
    )
    vuln_contract: Optional[str] = Field(
        default=None,
        description="The address of the vulnerable smart contract, if known.",
    )
    attacker_addr: Optional[str] = Field(
        default=None, description="The address of the attacker, if known."
    )
    attack_complexity: Literal["low", "medium", "high"] = Field(
        description="The complexity of the attack."
    )
    actor_name: Optional[str] = Field(
        default=None, description="The name of the attacker or group, if known."
    )
    actor_type: Optional[str] = Field(
        default=None,
        description="The type of actor involved in the incident. Either: individual, group, other (name).",
    )
    tags: List[str] = Field(
        description="A list of 4-10 short, lower-kebab tags (2-4 words each) describing the incident."
    )


tagging_instructions = """
Tagging rules (free-form; not from a fixed list):
- Produce 4-10 short tags; 2-4 words each; lower-kebab; no stopwords; no symbols.
- Produce 3-6 long tags; 5-12 words each; grammatical mini-phrases.
- Produce 4-10 keyphrases (noun phrases); plain text.
- Avoid duplicates and banalities (e.g., 'hack', 'crypto').

Examples: 'proxy-upgrade-takeover', 'flashloan-oracle-drift'
"""


def classify_incident(incident_description: str) -> Incident:
    """Classifies an incident description using Gemini Flash with structured output."""

    prompt = f"""
You extract a structured Incident. Use free-form semantic tags (no fixed vocab).
Follow these rules strictly.

{tagging_instructions}

Description:
{incident_description}
"""

    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt,
        config={
            "response_mime_type": "application/json",
            "response_schema": Incident,
            "thinking_config": {"thinking_budget": 0},
        },
    )

    inc: Incident = response.candidates[0].content.parts[0]
    return inc

# %%
def classify_incidents(incidents: dict) -> Tuple[bool, List[Incident]]:
    """Classifies multiple incident descriptions using Gemini Flash with structured output."""
    classified_incidents = []
    for i in incidents:
        try:
            incident = classify_incident(i["content"])
        except Exception as e:
            print(f"Error classifying incident: {e}")
            return False, classified_incidents
        classified_incidents.append({**i, **incident.model_dump()})
        print(json.loads(incident.text))
    return True, classified_incidents

# %%
# Classify Incidents and save
with open(incidents_file, "r") as f:
    data = json.load(f)
# data = [data[15]]  # Limit to one for testing
status, classified_incidents = classify_incidents(data)

with open(
    f"../data/incidents-dataset-20250906-classified{'-part' if not status else ''}.json",
    "w",
) as f:
    json.dump(classified_incidents, f, indent=2)
# Out:
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'Improper access control', 'total_value_extracted': '$4.5M', 'hack_date': '2021-06-15', 'hacked_app_name': 'Eleven Finance', 'hacked_app_website': None, 'vuln_contract': '0xdb2d590aCe7cAe51DF1fB3312738038Ec032Bf33', 'attacker_addr': '0xdb2d590aCe7cAe51DF1fB3312738038Ec032Bf33', 'attack_complexity': 'medium', 'actor_name': '0xdeadf4ce', 'actor_type': 'individual', 'tags': ['emergency-burn-exploit', 'flashloan-attack', 'yield-aggregator-exploit', 'bsc-exploit', 'nrv-vault-exploit', 'dumb-logic-issue', 'intermediate-vault-vulnerability', 'binance-smart-chain-hack']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Integer Underflow', 'total_value_extracted': '$5M', 'hack_date': '2025-03-05', 'hacked_app_name': '1inch Fusion v1 resolver', 'hacked_app_website': 'null', 'vuln_contract': '0xa88800cd213da5ae406ce248380802bd53b47647', 'attacker_addr': '0xa7264a43a57ca17012148c46adbc15a5f951766e', 'attack_complexity': 'medium', 'actor_name': 'null', 'actor_type': 'individual', 'tags': ['integer-underflow-exploit', 'deprecated-code-vulnerability', 'calldata-corruption', 'memory-pointer-hijack', 'audit-oversight-failure', 'negative-interaction-length', 'bounty-negotiation', 'partial-fund-return', 'legacy-code-exploit', 'resolver-contract-hack']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Compromised Keys', 'total_value_extracted': '$1.75 million', 'hack_date': '2022-03-24', 'hacked_app_name': '8ight Finance', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'low', 'actor_name': None, 'actor_type': None, 'tags': ['private-key-compromise', 'opsec-failure', 'multi-sig-lie', 'developer-rugpull-suspect', 'olympus-fork', 'harmony-chain', 'social-media-vulnerability', 'funds-to-tornado']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Access Control Vulnerability', 'total_value_extracted': '$1.18 million', 'hack_date': '2025-05-09', 'hacked_app_name': 'LNDFi', 'hacked_app_website': None, 'vuln_contract': '0xAA8cc9afE14f3A2B200CA25382e7C87CD883a527', 'attacker_addr': '0x5149A7696188F083297281D10293a20476252CDD', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['admin-key-compromise', 'backdoor-insertion', 'access-control-bypass', 'pre-planned-exploit', 'contract-modification', 'delayed-drain', 'single-point-failure']}
# {'proto': 'bnb', 'type': 'rugpull', 'exploit_type': 'liquidity drain', 'total_value_extracted': '$2.79M', 'hack_date': '2022-10-18', 'hacked_app_name': 'Lucky Star Currency, FSL', 'hacked_app_website': None, 'vuln_contract': '0x8923881e8cae6684c2bb84d69ae88a9bbbec8d5a', 'attacker_addr': '0x7249b903da533358c897784438b87bc94b402352', 'attack_complexity': 'low', 'actor_name': None, 'actor_type': None, 'tags': ['bsc-shitcoin-rug', 'pre-minted-token-dump', 'liquidity-drain', 'developer-wallet-drain', 'unverified-contract', 'privileged-function-abuse', 'tornado-cash-deposit', 'chinese-astrology-nft']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Rounding Error', 'total_value_extracted': '$6.5M', 'hack_date': '2024-01-09', 'hacked_app_name': 'Abracadabra', 'hacked_app_website': 'null', 'vuln_contract': '0x7259e152103756e1616A77Ae982353c3751A6a90, 0x692887E8877C6Dd31593cda44c382DB5b289B684', 'attacker_addr': '0x87f585809ce79ae39a5fa0c7c96d0d159eb678c9', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['rounding-issue', 'cauldron-v4-exploit', 'mim-depeg', 'flashloan-attack', 'debt-calculation-manipulation', 'erc-4626-vulnerability', 'liquidity-drain', 'yv-crv3crypto-cauldron', 'magicape-cauldron', 'on-chain-negotiations']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Logic Error', 'total_value_extracted': '$13M', 'hack_date': '2024-03-01', 'hacked_app_name': 'Abracadabra Money', 'hacked_app_website': 'https://abracadabramoney.com/', 'vuln_contract': '0x625Fe79547828b1B54467E5Ed822a9A8a074bD61', 'attacker_addr': '0xAF9e33Aa03CAaa613c3Ba4221f7EA3eE2AC38649', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['liquidation-loophole-exploit', 'phantom-collateral-vulnerability', 'failed-deposit-bug', 'self-liquidation-exploit', 'arbitrum-ethereum-bridge', 'defi-protocol-hack', 'smart-contract-vulnerability', 'post-audit-exploit', 'multi-chain-incident', 'financial-sleight-of-hand']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Misconfiguration', 'total_value_extracted': '$1.6M', 'hack_date': '2022-08-14', 'hacked_app_name': 'Acala Network', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '23bmUgSeKMD8Y9triphPw5YHuiz3QUJNqcbmb3Eg9QMQDMWN, 253pFTg22JqHbLeLZUpexGMDUuXAJLfEriTYkFqvGWPuwcFi', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['liquidity-pool-misconfiguration', 'erroneous-minting-bug', 'defi-hub-exploit', 'polkadot-ecosystem-attack', 'on-chain-activity-tracing', 'stablecoin-depeg-incident', 'governance-decision-impact', 'funds-transfer-disabled']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Re-entrancy', 'total_value_extracted': '$11.7M', 'hack_date': '2022-03-15', 'hacked_app_name': 'Agave DAO, Hundred Finance', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['re-entrancy-exploit', 'flash-loan-attack', 'gnosis-chain', 'xdai-token-vulnerability', 'aave-fork', 'compound-fork', 'code-reuse-risk', 'defi-hack']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Re-entrancy', 'total_value_extracted': '$2,000,000 DAI', 'hack_date': '2020-11-12', 'hacked_app_name': 'Akropolis', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['flash-loan-exploit', 're-entrancy-attack', 'malicious-token-contract', 'deposit-logic-flaw', 'defi-protocol-hack', 'audited-project-rekt', 'smart-contract-vulnerability', 'value-calculation-error', 'ethereum-blockchain-incident', 'user-trust-compromised']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Logic Error', 'total_value_extracted': '$6.5M', 'hack_date': '2021-09-17', 'hacked_app_name': 'Alchemix', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['undercollateralized-debt', 'protocol-debt', 'eth-lending', 'yield-farming', 'smart-contract-bug', 'community-appeal', 'liquidity-exploit']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'Compromised Private Key', 'total_value_extracted': '$4.3 million', 'hack_date': '2023-05-14', 'hacked_app_name': 'AlexLab XLink bridge', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x27055aE433E9DCb30f6EbCC1A374Cf5CC03C484E', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['private-key-compromise', 'phishing-attack', 'admin-key-takeover', 'vault-drainage', 'stx-token-theft', 'proxy-contract-upgrade', 'centralized-exchange-freezing', 'bounty-offer', 'token-reissuance-proposal', 'sloppy-opsec']}
# {'proto': 'btc', 'type': 'exploit', 'exploit_type': 'Logic Error', 'total_value_extracted': '$16.18M', 'hack_date': '2024-06-06', 'hacked_app_name': 'AlexLab', 'hacked_app_website': None, 'vuln_contract': 'SP102V8P0F7JX67ARQ77WEA3D3CFB5XW39REDT0AM.amm-vault-v2-01', 'attacker_addr': 'SP2VCNXGRZCBTP8E9MQ6DJPFVXRBPWBN63FE06A1M', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': 'individual', 'tags': ['self-listing-exploit', 'vault-drainage', 'fake-token-bypass', 'permission-escalation', 'liquidity-siphon', 'architectural-blindspot', 'double-rekt']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Logic Error/Insider Trading', 'total_value_extracted': '$37.5M', 'hack_date': '2021-02-13', 'hacked_app_name': 'Alpha Finance (Alpha Homora)', 'hacked_app_website': 'null', 'vuln_contract': 'null', 'attacker_addr': 'null', 'attack_complexity': 'high', 'actor_name': 'null', 'actor_type': 'individual', 'tags': ['complex-defi-deception', 'multi-transaction-attack', 'insider-information-required', 'sushi-pool-manipulation', 'debt-share-inflation', 'rounding-miscalculation', 'resolve-reserve-exploit', 'custom-spell-abuse', 'flashloan-leverage']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Hot Wallet Compromise', 'total_value_extracted': '$60M', 'hack_date': '2023-07-22', 'hacked_app_name': 'AlphaPo', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x040a96659fd7118259ebcd547771f6ecb9580d17, 0x6d2e8a20b8afa88d92406d315b67822c01e53c38, 0xde374094C837D192B61972172740BDAfc4eE16E0, TKSitnfTLVMRbJsF1i2UH5hNUeHLDrXDiY, TDoNAZHa7WxarUAFbQUhiijTGtd7EpbzRh, TJF7mdFxDuHB4tb9hoyR4SCpKxk7gr23ym', 'attack_complexity': 'high', 'actor_name': 'Lazarus Group', 'actor_type': 'group', 'tags': ['hot-wallet-drain', 'state-sponsored-attack', 'payments-processor-hack', 'multi-chain-exploit', 'lazarus-group-activity', 'spearphishing-vector', 'centralized-platform-breach', 'large-scale-theft']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$5M, $15.5M, $3.5M', 'hack_date': '2022-12-02', 'hacked_app_name': 'Ankr, Helio Money', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xf3a465c9fa6663ff50794c698f600faa4b05c777', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['private-key-compromise', 'supply-manipulation', 'oracle-manipulation', 'deployer-address-hack', 'token-mint-vulnerability', 'liquidity-drain', 'cross-chain-laundering', 'depeg-event', 'audit-failure']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Private Key Compromise', 'total_value_extracted': '$7.9M', 'hack_date': '2021-07-28', 'hacked_app_name': 'Anyswap', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x0aE1554860E51844B61AE20823eF1268C3949f7C', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['mpc-wallet-exploit', 'ecdsa-vulnerability', 'private-key-leak', 'cross-chain-bridge', 'stablecoin-theft', 'repeated-k-value', 'prototype-v3-hack', 'security-flaw-known']}
# {'proto': 'bnb', 'type': 'rugpull', 'exploit_type': 'honeypot', 'total_value_extracted': '$10M', 'hack_date': '2022-01-04', 'hacked_app_name': 'Arbix Finance', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x4714a26e4e2e1334c80575332ec9eb043b61a2c4', 'attack_complexity': 'low', 'actor_name': None, 'actor_type': None, 'tags': ['vault-drainage', 'exit-scam', 'defi-rugpull', 'arbitrage-scheme', 'pancakeswap-dump', 'multi-asset-theft', 'website-deletion', 'social-media-wipe']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Compromised Keys', 'total_value_extracted': '$77.7M', 'hack_date': '2021-12-11', 'hacked_app_name': 'AscendEX', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['hot-wallet-compromise', 'private-key-theft', 'multi-chain-exploit', 'centralized-exchange-hack', 'asset-depreciation', 'reimbursement-promise', 'suspended-withdrawals']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Reentrancy via IBC hooks', 'total_value_extracted': '60 million ASTRO, 3.5 million USDC, 500,000 USDT, 2.7 BTC ($6.4 million)', 'hack_date': '2023-07-30', 'hacked_app_name': 'Astroport', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': 'terra1wrve5z5vsmrgy6ldcveq93aldr6wk3qmxavs4j', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['reentrancy-vulnerability', 'ibc-hooks-exploit', 'known-vulnerability-reintroduced', 'accidental-patch-revert', 'cosmos-chain-hack', 'terra-ecosystem-impact', 'regulatory-action-oversight', 'security-warnings-ignored', 'token-factory-force-transfer', 'stolen-funds-frozen']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'Governance Takeover', 'total_value_extracted': '$2.5M', 'hack_date': '2023-06-07', 'hacked_app_name': 'Atlantis Loans', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xEADe071FF23bceF312deC938eCE29f7da62CF45b', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['governance-takeover', 'malicious-proposal', 'contract-upgrade', 'token-approvals-drain', 'abandoned-protocol-exploit', 'defi-lending-vulnerability', 'smart-contract-exploit', 'post-abandonment-hack']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Supply Chain Attack', 'total_value_extracted': '$100M', 'hack_date': '2023-06-02', 'hacked_app_name': 'Atomic Wallet', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'high', 'actor_name': 'Lazarus Group', 'actor_type': 'group', 'tags': ['multi-chain-exploit', 'supply-chain-attack', 'bcp-hijacking-potential', 'lazarus-group-activity', 'wallet-vulnerability-ignored', 'fund-laundering-mixer', 'desktop-mobile-affected', 'indiscriminate-drain']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Fake Token Attack', 'total_value_extracted': '$3.8 million', 'hack_date': '2021-03-09', 'hacked_app_name': 'DODO', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xa305fab8bda7e1638235b054889b3217441dd645, 0x56178a0d5f301baf6cf3e1cd53d9863437345bf9, 0x00000000e84f2bbdfb129ed6e495c7f879f3e634, 0x3554187576ec863af63eea81d25fbf6d3f3f13fc', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['fake-token-exploit', 'multiple-init-bug', 'crowdpool-drain', 'flash-loan-exploit', 'bot-frontrunning', 'returned-funds', 'defi-protocol-hack', 'smart-contract-vulnerability']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Governance Takeover', 'total_value_extracted': '$6M', 'hack_date': '2022-07-24', 'hacked_app_name': 'Audius', 'hacked_app_website': None, 'vuln_contract': '0xbdbb5945f252bc3466a319cdcc3ee8056bf2e569', 'attacker_addr': '0xa0c7BD318D69424603CBf91e9969870F21B8ab4c', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': 'individual', 'tags': ['governance-takeover', 'proxy-admin-collision', 'defi-hack', 'storage-slot-exploit', 'token-dump', 'treasury-drain', 'smart-contract-vulnerability', 'open-zeppelin-bug']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'flash-loan-attack', 'total_value_extracted': '$745k', 'hack_date': '2021-05-22', 'hacked_app_name': 'Autoshark', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['flash-loan-attack', 'price-oracle-manipulation', 'minting-exploit', 'defi-hack', 'bnb-chain-exploit', 'token-dump', 'reward-system-abuse']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Front-end attack', 'total_value_extracted': '$120 million', 'hack_date': '2021-12-02', 'hacked_app_name': 'Badger DAO', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x1fcdb04d0c5364fbd92c73ca8af9baa72c269107', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['front-end-compromise', 'infinite-approval-exploit', 'user-address-drained', 'wrapped-bitcoin-theft', 'malicious-transaction-pause', 'cloudflare-compromise-rumor', 'discord-vulnerability-flag', 'wallet-approval-hygiene', 'decentralized-finance-security', 'mass-adoption-hurdle']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Price Manipulation', 'total_value_extracted': '$2.1M', 'hack_date': '2023-09-08', 'hacked_app_name': 'Balancer', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xB23711b9D92C0f1c7b211c4E2DC69791c2df38c1, 0xed187f37e5ad87d5b3b2624c01de56c5862b7a9b, 0x429313e53a220c4a5693cad1da26ae5045b5762f, 0x64E08fa89C2bAE9F123cc8a293775f0E6CC86760, 0xBC794F1ff9AD7711A9d2E69Be5b499e290B8fD3c', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['amm-pool-exploit', 'vulnerability-disclosure-exploit', 'price-oracle-manipulation', 'linear-pool-rounding', 'boosted-pool-attack', 'multi-chain-exploit', 'balancer-protocol-hack']}
# {'proto': 'eth', 'type': 'rugpull', 'exploit_type': 'liquidity pull', 'total_value_extracted': '$23M', 'hack_date': '2023-07-31', 'hacked_app_name': 'BALD', 'hacked_app_website': None, 'vuln_contract': '0xccfa0530b9d52f970d1a2daea670ce58e4176389', 'attacker_addr': '0xccfa0530b9d52f970d1a2daea670ce58e4176389', 'attack_complexity': 'low', 'actor_name': None, 'actor_type': 'individual', 'tags': ['memecoin-rugpull', 'base-network-incident', 'liquidity-drain', 'deployer-exit-scam', 'early-stage-exploit', 'centralized-control', 'defi-degeneracy', 'pump-dump']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Telegram Message Oracle Manipulation', 'total_value_extracted': '$3M', 'hack_date': '2023-09-19', 'hacked_app_name': 'Banana Gun', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['telegram-oracle-exploit', 'cross-chain-exploit', 'trading-bot-vulnerability', 'wallet-drainage', 'smart-money-attack', 'concentrated-loss', 'security-flaws-revealed', 'defi-bot-attack']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Governance Takeover', 'total_value_extracted': '$181M', 'hack_date': '2022-04-17', 'hacked_app_name': 'Beanstalk Farms', 'hacked_app_website': None, 'vuln_contract': '0xe5ecf73603d98a0128f05ed30506ac7a663dbb69', 'attacker_addr': '0x1c5dcdd006ea78a7e4783f9e6021c32935a10fb4', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['flash-loan-exploit', 'governance-attack', 'voting-power-manipulation', 'no-execution-delay', 'malicious-proposal', 'liquidity-pool-exploit', 'tornado-cash-outflow', 'smart-contract-vulnerability', 'defi-hack']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'Logic Error', 'total_value_extracted': '$18M', 'hack_date': '2021-05-16', 'hacked_app_name': 'bEarnFi', 'hacked_app_website': None, 'vuln_contract': 'BvaultsBank contract', 'attacker_addr': '0x47f3...', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': 'individual', 'tags': ['logic-error', 'denomination-mistake', 'flashloan-attack', 'bsc-exploit', 'yield-farming-hack', 'bvaultsbank-exploit', 'ibbusd-manipulation', 'multiple-withdrawals', 'alpaca-finance-involvement']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Logic Error', 'total_value_extracted': '$2M', 'hack_date': '2023-09-25', 'hacked_app_name': 'Bedrock', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x2bFB373017349820dda2Da8230E6b66739BE9F96', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['native-token-mishandling', 'total-supply-manipulation', 'cap-restriction-bypass', 'unaudited-contract-upgrade', 'multi-chain-exploit', 'slow-response-time', 'defi-vulnerability', 'token-minting-exploit']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'Flash Loan Attack', 'total_value_extracted': '$6.3M', 'hack_date': '2021-05-29', 'hacked_app_name': 'Belt Finance', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['flash-loan-exploit', 'incorrect-share-valuation', 'bsc-protocol-hack', 'fork-of-fork', 'price-oracle-manipulation', 'liquidity-pool-exploit', 'collateral-manipulation', 're-entrancy-attack']}
# {'proto': 'other', 'type': 'rugpull', 'exploit_type': 'Access Control', 'total_value_extracted': '$1.75M', 'hack_date': '2021-12-12', 'hacked_app_name': 'Bent Finance', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x40375a93099981209b30c1737e467b8782d638ac', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['insider-rugpull', 'manual-balance-adjust', 'cvxcrv-exploit', 'rewards-manipulation', 'team-collusion', 'tornado-cash-out', 'defi-exploit-incident', 'privilege-abuse', 'whale-withdrawals', 'post-listing-discovery']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'hot wallet compromise', 'total_value_extracted': '$44.7M', 'hack_date': '2024-09-19', 'hacked_app_name': 'BingX', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xf7e8033366166f92eb477b7b38e0d47d47b43326, 0xb0146aec3593410c8307b570af69adf4d74678b3, 0x940362b46faf7df48af1c8989d809f50466b5fca, 0x1Dd7dAf089C16856155FeFd7e2170966bb6b3AEE, 0x719981cf7D1a1dC681a1cf0C6B1eeeE090D0FEd6, 0xf26e64ef4300ca027d2ffedd7d765d7a3906091c, 0xb77a4a9678315775c4ba89f18f84f87538e748f5, 0x63dc352ddfc17aa04edac47ce36e186c1e54b02c, 0x49284f0ab5098d7effb3392124903c081d1b9f7e, 0xcfc14fa81226074036622976d95897ff84b58d66', 'attack_complexity': 'high', 'actor_name': 'Lazarus Group (suspected)', 'actor_type': 'group', 'tags': ['centralized-exchange-hack', 'hot-wallet-compromise', 'multi-chain-exploit', 'sophisticated-hacking-group', 'lazarus-group-tactics', 'customer-fund-loss', 'pr-downplay-incident', 'security-vulnerability']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$196M', 'hack_date': '2021-12-02', 'hacked_app_name': 'BitMart', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x39fb0dcd13945b835d47410ae0de7181d3edf270', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'group', 'tags': ['hot-wallet-drain', 'centralized-exchange-hack', 'cross-chain-exploit', 'memecoin-theft', 'private-key-compromise', 'funds-washed-tornadocash']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Supply Chain Attack', 'total_value_extracted': '$8M', 'hack_date': '2023-07-02', 'hacked_app_name': 'Bittensor', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '5FbWTraF7jfBe5EvCmSThum85htcrEsCzwuFjG3PukTUQYot', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['pypi-package-compromise', 'supply-chain-attack', 'coldkey-details-theft', 'network-halt-response', 'tao-token-drain', 'malicious-package-injection', 'validator-wallet-exploit', 'centralized-control-issue']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'Forged Proofs/Bridge Exploit', 'total_value_extracted': '$586M', 'hack_date': '2022-10-06', 'hacked_app_name': 'BNB Bridge (BSC Token Hub)', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x489a8756c18c0b8b24ec2a2b9ff3d4d447f79bec', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': 'individual', 'tags': ['cross-chain-bridge', 'forged-proofs', 'iav-verification-bug', 'bnb-chain-pause', 'liquidity-drain', 'centralization-concerns', 'post-hack-measures', 'funds-bridged-offchain']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Infinite Mint', 'total_value_extracted': '$5.9M', 'hack_date': '2021-07-16', 'hacked_app_name': 'Bondly Finance', 'hacked_app_website': None, 'vuln_contract': '0x58a058ca4b1b2b183077e830bc929b5eb0d3330c', 'attacker_addr': '0xc433d50dd0614c81ee314289ec82aa63710d25e8', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['infinite-mint-exploit', 'token-price-manipulation', 'celebrity-partnership-impact', 'community-trust-erosion', 'defi-protocol-rekt', 'market-dump-attack', 'wallet-compromise-claim', 'smart-contract-vulnerability']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Price Oracle Manipulation', 'total_value_extracted': '$120M', 'hack_date': '2023-02-01', 'hacked_app_name': 'BonqDAO', 'hacked_app_website': None, 'vuln_contract': '0x8f55d884cad66b79e1a131f6bcb0e66f4fd84d5b', 'attacker_addr': '0xcacf2d28b2a5309e099f0c6e8c60ec3ddf656642', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['oracle-manipulation', 'polygon-lending-protocol', 'tellor-price-feed', 'inflated-collateral-borrow', 'liquidation-attack', 'stablecoin-depeg', 'unaudited-contract', 'allianceblock-collateral-damage']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'admin-key-compromise', 'total_value_extracted': '$1.1 million (290 ETH)', 'hack_date': '2021-12-14', 'hacked_app_name': 'BrincFi', 'hacked_app_website': None, 'vuln_contract': '0x09ae252d00122864070461e78810a3b91c4fb64076f72eb6dba775a80ca00df4', 'attacker_addr': '0x6B0b61323F6d77ef8A1a35D11FA877631d8f67Bb', 'attack_complexity': 'medium', 'actor_name': 'Daniel Choi (alleged)', 'actor_type': 'individual', 'tags': ['admin-key-exploit', 'insider-threat', 'privilege-escalation', 'supply-chain-attack', 'contract-upgrade-vulnerability', 'developer-betrayal', 'fund-drain', 'tornado-cash-laundering', 'legal-battle', 'slow-justice']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'Re-entrancy', 'total_value_extracted': '$7.2M', 'hack_date': '2021-05-28', 'hacked_app_name': 'BurgerSwap', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['flash-swap-exploit', 'reentrancy-vulnerability', 'missing-x-y-k-check', 'bep20-fake-token', 'liquidity-pool-manipulation', 'defi-hack-bnb', 'price-oracle-manipulation', 'copycat-protocol-vulnerability']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Front-end Spoofing, Blind Signing, Smart Contract Vulnerability', 'total_value_extracted': '$1.43 billion', 'hack_date': '2024-07-26', 'hacked_app_name': 'ByBit', 'hacked_app_website': None, 'vuln_contract': '0x1Db92e2EeBC8E0c075a02BeA49a2935BcD2dFCF4', 'attacker_addr': '0x47666Fab8bd0Ac7003bce3f5C3585383F09486E2', 'attack_complexity': 'high', 'actor_name': 'Lazarus Group', 'actor_type': 'group', 'tags': ['front-end-spoofing', 'multisig-compromise', 'blind-signing', 'state-sponsored-hack', 'cold-wallet-drain', 'supply-chain-attack', 'sophisticated-malware', 'social-engineering']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'phishing-attack', 'total_value_extracted': '$55M', 'hack_date': '2022-02-18', 'hacked_app_name': 'bZx', 'hacked_app_website': 'bzx.network', 'vuln_contract': None, 'attacker_addr': '0x4b7875b42661a384b64e83fdf4009c253b347b9c', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['phishing-exploit', 'developer-wallet-compromise', 'private-key-theft', 'supply-chain-attack', 'malicious-macro', 'token-approval-drain', 'cross-chain-fund-movement', 'social-engineering-attack']}
# {'proto': 'sol', 'type': 'exploit', 'exploit_type': 'Infinite Mint / Incomplete Collateral Validation', 'total_value_extracted': '$48M', 'hack_date': '2022-03-22', 'hacked_app_name': 'Cashio', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'high', 'actor_name': None, 'actor_type': 'individual', 'tags': ['solana-infinite-mint', 'collateral-validation-bypass', 'fake-root-contract', 'saber-swap-exploit', 'lp-token-vulnerability', 'partial-funds-return', 'anonymous-attacker', 'cross-chain-bridge']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Bug Bounty Abuse', 'total_value_extracted': '$3M', 'hack_date': '2024-06-09', 'hacked_app_name': 'Kraken', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': 'Certik', 'actor_type': 'group', 'tags': ['bug-bounty-dispute', 'security-firm-exploit', 'account-balance-inflation', 'corporate-wallet-drain', 'vulnerability-disclosure-conflict', 'ethical-hacking-controversy', 'platform-security-breach', 'tornado-cash-involvement']}
# {'proto': 'sol', 'type': 'exploit', 'exploit_type': 'Precision/Rounding Error', 'total_value_extracted': '$60M', 'hack_date': '2024-05-22', 'hacked_app_name': 'Cetus Protocol', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xe28b50cef1d633ea43d3296a3f6b67ff0312a5f1a99f0af753c85b8b5de8ff06', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['math-error-exploit', 'liquidity-pool-drain', 'sui-ecosystem-risk', 'amm-vulnerability', 'precision-error-hack', 'flashloan-attack', 'wormhole-bridge', 'validator-intervention', 'bounty-offer-failed', 'shared-library-bug']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Proxy contract exploit', 'total_value_extracted': '$4.4M', 'hack_date': '2021-08-01', 'hacked_app_name': 'ChainSwap', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xEda5066780dE29D00dfb54581A707ef6F52D8113', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['cross-chain-bridge-exploit', 'proxy-contract-vulnerability', 'token-minting-exploit', 'sloppy-auth-bypass', 'multi-chain-attack', 'defi-bridge-hack', 'asset-depletion', 'attacker-cashout', 'suspicious-correspondence', 'unlaundered-funds']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Re-entrancy', 'total_value_extracted': '$500k', 'hack_date': '2023-11-09', 'hacked_app_name': 'Clober Dex', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x012Fc6377F1c5CCF6e29967Bce52e3629AaA6025', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['dex-liquidity-vault-hack', 'post-audit-code-change', 'unreviewed-code-deployment', 'burn-function-exploit', 'callback-abuse', 'incomplete-state-updates', 'cross-chain-fund-movement', 'security-audit-failure', 'protocol-security-lapse', 'bounty-offered-attacker']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$54.3M', 'hack_date': '2023-09-12', 'hacked_app_name': 'CoinEx', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'high', 'actor_name': 'Lazarus Group', 'actor_type': 'group', 'tags': ['centralized-exchange-hack', 'hot-wallet-drain', 'multi-chain-exploit', 'state-sponsored-attack', 'private-key-compromise', 'large-scale-theft', 'custodian-security-breach', 'defi-incident', 'cyber-heist']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Logic Error', 'total_value_extracted': '$147M', 'hack_date': '2021-10-01', 'hacked_app_name': 'Compound', 'hacked_app_website': None, 'vuln_contract': '0x6d903f6003cca6255D85CcA4D3B5E5146dC33925', 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['compound-comptroller-bug', 'excess-comp-distribution', 'governance-proposal-error', 'drip-function-abuse', 'uncontrolled-funds-drain', 'reputation-damage-control', 'defi-code-is-law', 'protocol-logic-vulnerability']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Read-only Reentrancy & Sandwich Attack', 'total_value_extracted': '$4.2M', 'hack_date': '2023-07-21', 'hacked_app_name': 'Conic Finance', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x8d67db0b205e32a5dd96145f022fa18aae7dc8aa', 'attack_complexity': 'medium', 'actor_name': 'LadyPepe Token Exploiter', 'actor_type': 'individual', 'tags': ['read-only-reentrancy', 'oracle-manipulation', 'sandwich-attack', 'omnipool-exploit', 'frontrun-attack', 'audit-miss', 'eth-weth-confusion', 'imbalanced-pool-drain']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Improper Input Validation', 'total_value_extracted': '$12M', 'hack_date': '2024-05-28', 'hacked_app_name': 'Cork Protocol', 'hacked_app_website': None, 'vuln_contract': '0xccd90f6435dd78c4ecced1fa4db0d7242548a2a9', 'attacker_addr': '0xEA6f30e360192bae715599E15e2F765B49E4da98', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['fake-token-manipulation', 'exchange-rate-exploit', 'arbitrary-redemption-assets', 'unauthorized-function-call', 'missing-input-validation', 'out-of-scope-audit', 'wsteth-drainage', 'depeg-insurance-failure']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'infinite-mint-vulnerability', 'total_value_extracted': '$9.4M ($3.2M recovered)', 'hack_date': '2020-12-28', 'hacked_app_name': 'Cover Protocol', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': 'Grap Finance', 'actor_type': 'group', 'tags': ['infinite-mint-exploit', 'yield-farming-manipulation', 'token-supply-inflation', 'white-hat-pretender', 'balancer-pool-exploit', 'defi-insurance-vulnerability', 'opsec-failure-attacker', 'multisig-contract-exploit', 'community-refund-plan']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Re-entrancy', 'total_value_extracted': '$18.8M', 'hack_date': '2021-02-10', 'hacked_app_name': 'Cream Finance', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xce1f4b4f17224ec6df16eeb1e3e5321c54ff6ede', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['amp-token-reentrancy', 'flashloan-attack-vector', 'borrow-function-exploit', 'crETH-collateral-abuse', 'vulnerable-token-integration', 'defi-protocol-hack', 'smart-contract-exploit', 'post-audit-vulnerability']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Price Oracle Manipulation', 'total_value_extracted': '$130M', 'hack_date': '2021-10-27', 'hacked_app_name': 'Cream Finance', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x20760431b994d306b3a01dd28290f8457630739e', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['defi-lending-exploit', 'flashloan-attack', 'oracle-price-manipulation', 'yearn-ecosystem-incident', 'recursive-borrow-loop', 'token-price-exploit']}
# {'proto': 'sol', 'type': 'exploit', 'exploit_type': 'Logic Error', 'total_value_extracted': '69422.9 SOL, 6,497,738 USDCet', 'hack_date': '2022-07-02', 'hacked_app_name': 'Crema Finance', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': 'Esmx2QjmDZMjJ15yBJ2nhqisjEt7Gqro4jSkofdoVsvY', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['faulty-owner-validation', 'fake-tick-account', 'flashloan-attack', 'lp-fee-manipulation', 'unpatched-vulnerability', 'cross-chain-bridge', 'bounty-negotiation', 'solana-ethereum']}
# {'proto': 'btc', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$33.7M', 'hack_date': '2022-01-17', 'hacked_app_name': 'Crypto.com', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': 'bc1q7cyrfmck2ffu2ud3rn5l5a8yv6f0chkp0zpemf', 'attack_complexity': 'high', 'actor_name': 'Lazarus Group', 'actor_type': 'group', 'tags': ['centralized-exchange-exploit', '2fa-bypass', 'withdrawal-whitelist-bypass', 'btc-tumbler-laundering', 'user-funds-drained', 'security-audit-failure', 'cryptocom-denial', 'multi-chain-exploit', 'hot-wallet-vulnerability', 'unauthorized-activity']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Governance Manipulation', 'total_value_extracted': '$16M', 'hack_date': '2024-03-23', 'hacked_app_name': 'Curio DAO', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xdaAa6294C47b5743BDafe0613d1926eE27ae8cf5', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': 'individual', 'tags': ['voting-power-exploit', 'makerdao-fork-vulnerability', 'token-minting-scheme', 'cross-chain-transfers', 'governance-takeover', 'defi-exploit', 'smart-contract-vulnerability', 'access-control-bypass']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'DNS Hijacking', 'total_value_extracted': '$575k', 'hack_date': '2022-08-09', 'hacked_app_name': 'Curve Finance', 'hacked_app_website': 'curve.fi', 'vuln_contract': '0x9eb5f8e83359bb5013f3d8eee60bdce5654e8881', 'attacker_addr': '0x50f9202e0f1c1577822bd67193960b213cd2f331', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['dns-hijacking', 'front-end-exploit', 'web2-dependency', 'approval-harvesting', 'nameserver-compromise', 'centralized-infrastructure', 'user-trust-exploit', 'defi-security-lapse']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Compiler Bug/Re-entrancy', 'total_value_extracted': '$69M', 'hack_date': '2023-07-30', 'hacked_app_name': 'Curve Finance (and integrated protocols)', 'hacked_app_website': 'https://curve.fi/', 'vuln_contract': None, 'attacker_addr': '0x6ec21d1868743a44318c3c259a6d4953f9978538, 0xdce5d6b41c32f578f875efffc0d422c57a75d7d8, 0xB1C33b391C2569B737eC387E731E88589e8ec148, 0xb752def3a1fded45d6c4b9f4a8f18e645b41b324', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['vyper-compiler-bug', 'reentrancy-vulnerability', 'curve-pools-drain', 'defi-liquidation-risk', 'lp-token-manipulation', 'whitehat-intervention-attempt', 'critical-infrastructure-exploit', 'storage-slot-misalignment']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$4M', 'hack_date': '2021-08-01', 'hacked_app_name': 'DAO Maker', 'hacked_app_website': None, 'vuln_contract': '0x6e70c88be1d5c2a4c0c8205764d01abe6a3d2e22, 0xd6c8dd834abeeefa7a663c1265ce840ca457b1ec, 0xdd571023d95ff6ce5716bf112ccb752e86212167, 0xa43b89d5e7951d410585360f6808133e8b919289', 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['reinitialization-vulnerability', 'emergency-exit-exploit', 'multiple-token-drain', 'dao-maker-re-rekt', 'audit-failures', 'bad-security-practices', 'post-exploit-swap', 'potential-whitehat-recovery']}
# {'proto': 'eth', 'type': 'rugpull', 'exploit_type': 'Access Control', 'total_value_extracted': '$12,464,316.329', 'hack_date': '2020-11-23', 'hacked_app_name': 'Compounder Finance', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x944f214a343025593d8d9fd2b2a6d43886fb2474, 0x079667f4f7a0b440ad35ebd780efd216751f0758', 'attack_complexity': 'medium', 'actor_name': 'keccak (Vlad)', 'actor_type': 'individual', 'tags': ['malicious-strategy-contracts', 'unmonitored-timelock', 'centralized-admin-control', 'missing-withdraw-checks', 'post-audit-code-swap', 'anon-dev-rugpull', 'tornado-cash-funding', 'large-defi-rugpull']}
# {'proto': 'bnb', 'type': 'rugpull', 'exploit_type': 'Backdoor Function', 'total_value_extracted': '$1.6M', 'hack_date': '2023-08-01', 'hacked_app_name': 'DeFiLabs', 'hacked_app_website': None, 'vuln_contract': '0xdEDbd1804569F369e33e453Ee311F0F97dCd0Bde', 'attacker_addr': '0xee08d6c3a983eb22d7137022f0e9f5e7d4cf0be2', 'attack_complexity': 'low', 'actor_name': None, 'actor_type': None, 'tags': ['bsc-rugpull', 'backdoor-drain', 'staking-contract-exploit', 'centralization-vulnerability', 'audit-circumvention', 'shitcoin-casino']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Compromised Keys', 'total_value_extracted': '$10M', 'hack_date': '2023-01-01', 'hacked_app_name': 'Dego Finance', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x118203b0f2a3ef9e749d871c8fef5e5e55ef5c91', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['compromised-keys', 'multi-chain-exploit', 'lp-token-theft', 'token-minting-exploit', 'price-manipulation', 'private-key-compromise', 'lack-of-multi-sig', 'defi-security-failure']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Private Key Compromise', 'total_value_extracted': '$5.98M', 'hack_date': '2023-10-09', 'hacked_app_name': 'DeltaPrime', 'hacked_app_website': None, 'vuln_contract': '0xd550cfeA0BFFDC81B2dEe7B6d915D9D9e31d83A2', 'attacker_addr': '0x40E4172e595Fb5B3076dC6d0A1a24d885b881Afb', 'attack_complexity': 'high', 'actor_name': 'Lazarus Group (suspected)', 'actor_type': 'group', 'tags': ['private-key-compromise', 'admin-key-hack', 'arbitrum-exploit', 'proxy-contract-upgrade', 'deposit-amount-inflation', 'state-sponsored-attack', 'defi-security-lapse', 'multi-protocol-theft', 'laundered-funds', 'cold-wallet-bypass']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'unchecked-input-validation', 'total_value_extracted': '$4.85M', 'hack_date': '2023-11-20', 'hacked_app_name': 'DeltaPrime', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xb87881637b5c8e6885c51ab7d895e53fa7d7c567', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['unchecked-input-exploit', 'arbitrary-input-vulnerability', 'flash-loan-attack', 'cross-chain-exploit', 'yield-farming-stolen-funds', 'periphery-adaptor-flaw', 'avalanche-arbitrum-hack', 'multiple-vulnerabilities-combined', 'repeated-protocol-exploit', 'security-audit-ignored']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Compromised Keys', 'total_value_extracted': '$28M', 'hack_date': '2022-11-01', 'hacked_app_name': 'Deribit', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xb0606f433496bf66338b8ad6b6d51fc4d84a44cd', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['centralized-exchange-hack', 'hot-wallet-compromise', 'bitcoin-ethereum-loss', 'phishing-attack-suspected', 'company-reserves-cover', 'multi-chain-exploit', 'deposit-address-regeneration', 'potential-bounty-settlement']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Improper Access Control', 'total_value_extracted': '$6.5M', 'hack_date': '2023-03-24', 'hacked_app_name': 'Deus DAO', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x189cf534de3097c08b6beaf6eb2b9179dab122d1', 'attack_complexity': 'low', 'actor_name': None, 'actor_type': None, 'tags': ['burnfrom-misconfiguration', 'parameter-order-bug', 'multichain-exploit', 'stablecoin-depeg', 'public-burn-vulnerability', 'arbitrum-bsc-ethereum', 'frontrun-recovery', 'triply-hacked-protocol', 'smart-contract-bug', 'defi-exploit']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Price Oracle Manipulation', 'total_value_extracted': '$3M', 'hack_date': '2022-04-29', 'hacked_app_name': 'Deus DAO', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xe374495036fac18aa5b1a497a17e70f256c4d3d416dd1408c026f3f5c70a3a9c', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['flash-loan-attack', 'price-oracle-manipulation', 'dei-lending-contract', 'liquidation-exploit', 'defi-hack', 'collateral-value-manipulation', 'multichain-funds-movement', 'tornado-cash-mixer']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Price Oracle Manipulation', 'total_value_extracted': '$13.4M', 'hack_date': '2022-04-28', 'hacked_app_name': 'Deus DAO', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x701428a96495b2c9430b808940e4f3c7e3f22718', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['oracle-manipulation', 'flash-loan', 'solidly-exploit', 'muon-oracle-bypass', 'single-price-source', 'inadequate-filtering', 'defi-lending-exploit', 'tornado-cash-funds', 'fantom-ethereum-bridge', 'protocol-insolvency']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$2M', 'hack_date': '2023-11-24', 'hacked_app_name': 'Dexible', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x684083f312ac50f538cc4b634d85a2feafaab77a', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['unverified-router-address', 'self-swap-vulnerability', 'token-contract-call', 'transfer-from-exploit', 'unaudited-code', 'cross-chain-exploit', 'poor-crisis-communication', 'delayed-announcement', 'blocktower-capital-loss']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Re-entrancy', 'total_value_extracted': '$3.65M', 'hack_date': '2023-05-25', 'hacked_app_name': 'dForce Network', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xe0d551017c0111ac11108641771897aa33b2817c', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['reentrancy-vulnerability', 'curve-pool-exploit', 'oracle-manipulation', 'flashloan-attack', 'funds-returned', 'arbitrum-optimism', 'defi-hack', 'cross-chain-exploit']}
# {'proto': 'btc', 'type': 'exploit', 'exploit_type': 'private key compromise', 'total_value_extracted': '$304M', 'hack_date': '2024-05-31', 'hacked_app_name': 'DMM Bitcoin', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '1B6rJRfjTXwEy36SCs5zofGMmdv2kdZw7P', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['exchange-hot-wallet', 'private-key-compromise', 'address-spoofing', 'centralized-exchange-exploit', 'major-bitcoin-theft', 'japan-crypto-incident', 'security-incident-investigation', 'bounty-program-recovery']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Price Oracle Manipulation', 'total_value_extracted': '$9M', 'hack_date': '2023-11-24', 'hacked_app_name': 'dYdX', 'hacked_app_website': 'https://dydx.exchange/', 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['yfi-price-manipulation', 'insurance-fund-drain', 'market-manipulation-attack', 'targeted-liquidation-event', 'single-actor-exploit', 'dydx-v3-exploit', 'defi-protocol-attack', 'large-open-interest', 'token-price-crash', 'margin-trading-exploit']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Compromised Mnemonic Keys', 'total_value_extracted': '$6M stablecoins, $53M EASY tokens', 'hack_date': '2021-04-19', 'hacked_app_name': 'EasyFi', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['mnemonic-key-compromise', 'admin-key-theft', 'poor-opsec', 'single-point-failure', 'polygon-network-hack', 'treasury-drain', 'liquidity-loss', 'insufficient-security-measures']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'Price Oracle Manipulation', 'total_value_extracted': '$22.2M', 'hack_date': '2022-04-12', 'hacked_app_name': 'Elephant Money', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['flash-loan-attack', 'price-oracle-manipulation', 'stablecoin-exploit', 'token-minting-vulnerability', 'arbitrage-exploit', 'elephant-token-price-drop', 'audit-failure', 'defi-exploit', 'cross-chain-transfer', 'tornado-cash-laundering']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Flash Loan Manipulation', 'total_value_extracted': '$15M', 'hack_date': '2020-09-28', 'hacked_app_name': 'Eminence Finance', 'hacked_app_website': 'https://eminence.finance', 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['flash-loan-exploit', 'price-oracle-manipulation', 'unaudited-contract', 'bonding-curve-exploit', 'arbitrage-attack', 'andre-cronje-project', 'defi-exploit', 'partial-funds-return']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'private key compromise', 'total_value_extracted': '$150M', 'hack_date': '2020-09-25', 'hacked_app_name': 'Kucoin', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x00600423c03ec4b46f9b8a28c66d42bdd1b19c36', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['exchange-hot-wallet', 'private-key-compromise', 'erc20-token-freeze', 'centralized-response', 'multiple-asset-theft', 'attacker-laundering-fail', 'employee-insider-attack', 'btc-theft-included']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Read-only Reentrancy', 'total_value_extracted': '$3.4M', 'hack_date': '2023-07-28', 'hacked_app_name': 'EraLend', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xf1D076c9Be4533086f967e14EE6aFf204D5ECE7a', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['read-only-reentrancy', 'oracle-price-manipulation', 'syncswap-code-reuse', 'improper-implementation', 'ignored-developer-comment', 'lending-protocol-exploit', 'zksync-era-hack', 'lp-token-burning', 'audit-scope-limitation', 'defi-vulnerability']}
# ...
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Logic Error', 'total_value_extracted': '$27.6M', 'hack_date': '2022-06-05', 'hacked_app_name': 'Wintermute', 'hacked_app_website': 'null', 'vuln_contract': '0x4f3a120e72c76c22ae802d129f599bfdbc31cb81', 'attacker_addr': 'null', 'attack_complexity': 'high', 'actor_name': 'null', 'actor_type': 'null', 'tags': ['gnosis-safe-proxy', 'address-hijacking', 'create-opcode-vulnerability', 'optimism-token-loss', 'market-maker-exploit', 'multisig-address-error', 'transaction-replay-attack', 'old-proxy-factory', 'uncontrolled-funds-access', 'governance-risk']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Private Key Compromise', 'total_value_extracted': '$160M', 'hack_date': '2022-09-20', 'hacked_app_name': 'Wintermute', 'hacked_app_website': None, 'vuln_contract': '0x0248f752802b2cfb4373cc0c3bc3964429385c26', 'attacker_addr': '0xe74b28c2eAe8679e3cCc3a94d5d0dE83CCB84705', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['vanity-address-exploit', 'profanity-tool-vulnerability', 'hot-wallet-compromise', 'defi-operations-hack', 'private-key-theft', 'stablecoin-drain', 'curve-3pool-deposit', 'admin-address-compromise']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'price-oracle-manipulation', 'total_value_extracted': '$8.5M', 'hack_date': '2024-03-05', 'hacked_app_name': 'Woofi', 'hacked_app_website': None, 'vuln_contract': 'WooPPV2', 'attacker_addr': '0x9961190b258897bca7a12b8f37f415e689d281c4', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['flash-loan-attack', 'oracle-manipulation', 'price-oracle-exploit', 'arbitrum-exploit', 'woo-token-price-manipulation', 'spmm-system-vulnerability', 'cross-chain-risk', 'defi-hack']}
# {'proto': 'sol', 'type': 'exploit', 'exploit_type': 'Signature Verification Bypass', 'total_value_extracted': '$326M', 'hack_date': '2022-02-02', 'hacked_app_name': 'Wormhole Bridge', 'hacked_app_website': 'https://wormhole.com/', 'vuln_contract': None, 'attacker_addr': '0x629e7da20197a5429d30da36e77d06cdf796b71a', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': 'individual', 'tags': ['cross-chain-exploit', 'signature-spoofing', 'wrapped-eth-minting', 'solana-bridge-hack', 'vaa-verification-bypass', 'secp256k1-discrepancy', 'guardian-bypass', 'token-minting-exploit', 'solana-ecosystem-attack', 'defi-bridge-vulnerability']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Flash Loan Attack', 'total_value_extracted': '$24M', 'hack_date': '2021-05-08', 'hacked_app_name': 'xToken', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['flash-loan-exploit', 'price-oracle-manipulation', 'defi-protocol-hack', 'yield-farming-drain', 'snx-bnt-pools', 'dydx-flashloan', 'arbitrage-attack', 'mev-private-transaction', 'uniswap-v2-vulnerability']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$4.5M', 'hack_date': '2021-02-12', 'hacked_app_name': 'X-Token', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x924e6a6288587b497f73ddcf6ae3c184f15ab35dfcb85f3074b55266974029ef', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['flash-loan', 'access-control-vulnerability', 'price-manipulation', 'erroneous-require-statement', 'xsnx-contract', 'defi-exploit', 'arbitrage-opportunity']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Flash Loan Attack', 'total_value_extracted': '$11M', 'hack_date': '2021-02-04', 'hacked_app_name': 'Yearn DAI v1 vault', 'hacked_app_website': None, 'vuln_contract': '0x62494b3ed9663334e57f23532155ea0575c487c5', 'attacker_addr': '0x62494b3ed9663334e57f23532155ea0575c487c5', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': 'individual', 'tags': ['flash-loan-exploit', 'arbitrage-attack', 'curve-liquidity-drain', 'vault-migration-vulnerability', 'defi-blue-chip-hack', 'complex-transaction-chain', 'tether-funds-frozen', 'economic-manipulation']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Logic Error', 'total_value_extracted': '$11.4M', 'hack_date': '2023-04-13', 'hacked_app_name': 'Yearn Finance', 'hacked_app_website': 'https://yearn.finance/', 'vuln_contract': None, 'attacker_addr': '0x5bac20beef31d0eccb369a33514831ed8e9cdfe0', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['misconfiguration-exploit', 'copy-paste-error', 'yusdt-contract-vulnerability', 'share-price-manipulation', 'deprecated-strategy-loss', 'tornado-cash-funding', 'long-term-vulnerability', 'defi-protocol-incident']}
# {'proto': 'eth', 'type': 'rugpull', 'exploit_type': 'exit scam', 'total_value_extracted': '$33M', 'hack_date': '2024-04-20', 'hacked_app_name': 'ZKasino', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'medium', 'actor_name': 'Ildar Elham (Derivatives Ape)', 'actor_type': 'individual', 'tags': ['rugpull-exit-scam', 'eth-conversion-theft', 'misleading-marketing', 'founder-shady-past', 'unpaid-employees', 'canceled-ido', 'user-funds-staked', 'arbitrum-nitro-chain']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Precision Loss', 'total_value_extracted': '$9.57M (2,200 ETH, USDC, STRK, USDT)', 'hack_date': '2024-02-11', 'hacked_app_name': 'zkLend', 'hacked_app_website': None, 'vuln_contract': '0x04c0a5193d58f74fbace4b74dcf65481e734ed1714121bdc571da345540efa05', 'attacker_addr': '0x04d7191dc8eac499bac710dd368706e3ce76c9945da52535de770d06ce7d3b26', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': 'individual', 'tags': ['rounding-error', 'mathematical-manipulation', 'lending-accumulator-exploit', 'starknet-defi-hack', 'flashloan-attack', 'era-lend-exploiter', 'privacy-mixer-rejection', 'audit-bypass']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$8.4M', 'hack_date': '2024-03-21', 'hacked_app_name': 'Zoth', 'hacked_app_website': None, 'vuln_contract': '0x82f3a0392F58C50fa90542519832471BaE93e43e', 'attacker_addr': '0x3b33c5Cd948Be5863b72cB3D6e9C0b36E67d01E5', 'attack_complexity': 'low', 'actor_name': None, 'actor_type': None, 'tags': ['admin-key-compromise', 'contract-swap', 'funds-drained', 'proxy-contract-upgrade', 'stolen-credentials', 'deployer-wallet-compromise', 'real-world-asset-protocol-exploit', 'lax-key-management', 'repeated-exploit', 'insider-threat-potential']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Price Manipulation', 'total_value_extracted': '$2.1M', 'hack_date': '2023-08-14', 'hacked_app_name': 'Zunami Protocol', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x5f4c21c9bb73c8b4a296cc256c0cde324db146df', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['price-manipulation-attack', 'stablecoin-depeg', 'flash-loan-exploit', 'liquidity-pool-drain', 'flawed-price-calculation', 'curve-ecosystem-exploit', 'tornado-cash-deposit']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$500K', 'hack_date': '2025-05-14', 'hacked_app_name': 'Zunami Protocol', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x051370419b871f7c05dee8f7134401530832e250', 'attack_complexity': 'low', 'actor_name': None, 'actor_type': None, 'tags': ['admin-key-compromise', 'privileged-access-exploit', 'emergency-function-abuse', 'insider-job-suspicion', 'abandoned-development', 'protocol-mismanagement', 'multi-exploit-history', 'value-extraction-incident']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$3.6M', 'hack_date': '2024-07-15', 'hacked_app_name': 'ArcadiaFi', 'hacked_app_website': None, 'vuln_contract': '0xC729213B9b72694F202FeB9cf40FE8ba5F5A4509', 'attacker_addr': '0x0fa54e967a9cc5df2af38babc376c91a29878615', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['arbitrary-calldata-execution', 'rebalancer-contract-exploit', 'flashloan-assisted-attack', 'permission-escalation', 'unchecked-external-call', 'audit-blind-spot', 'emergency-pause-lockout', 'multi-stage-exploit']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'LP Manipulation / Infinite Minting', 'total_value_extracted': '$5 million', 'hack_date': '2024-05-20', 'hacked_app_name': 'BetterBank', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x48c9f537f3f1a2c95c46891332E05dA0D268869B', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': None, 'tags': ['lp-manipulation', 'infinite-minting-exploit', 'bonus-minting-abuse', 'auditor-warning-ignored', 'pulsechain-protocol-drain', 'tornado-cash-funded', 'custom-exploit-contracts', 'partial-asset-return']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Supply Chain Attack', 'total_value_extracted': '$27M', 'hack_date': '2023-07-15', 'hacked_app_name': 'BigONE', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': 'bc1qwxm53zya6cuflxhcxy84t4c4wrmgrwqzd07jxm, 0x9Bf7a4dDcA405929dba1FBB136F764F5892A8a7a, TKKGH8bwmEEvyp3QkzDCbK61EwCHXdo17c, HSr1FNv266zCnVtUdZhfYrhgWx1a4LNEpMPDymQzPg4R', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['supply-chain-compromise', 'production-server-hijack', 'account-logic-rewrite', 'risk-control-bypass', 'internal-network-breach', 'multi-chain-drain', 'infrastructure-exploit', 'unauthorized-withdrawal']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Private Key Compromise', 'total_value_extracted': '$51.7 million', 'hack_date': '2025-08-14', 'hacked_app_name': 'BTCTurk', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x7d91d1ebeba91257733a523409125aedac5d8b6e,0xb4b537626e21df5386cf167d1e654b38785056cc,0xa041feb3a8297c5689fee180083164a061a17fd6', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'group', 'tags': ['private-key-compromise', 'hot-wallet-drain', 'multi-chain-exploit', 'exchange-security-failure', 'repeat-incident', 'asset-consolidation', 'cross-chain-transfer', 'altcoin-to-eth-swap']}
# {'proto': 'other', 'type': 'exploit', 'exploit_type': 'Server Breach', 'total_value_extracted': '$44.3M', 'hack_date': '2024-07-18', 'hacked_app_name': 'CoinDCX', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0xEF0c5b9E0E9643937D75C229648158584A8CD8D2', 'attack_complexity': 'high', 'actor_name': 'Lazarus Group (possible)', 'actor_type': 'group', 'tags': ['sophisticated-server-breach', 'cross-chain-fund-laundering', 'exchange-wallet-drain', 'delayed-transparency-disclosure', 'blockchain-detective-exposure', 'premeditated-attack-preparation', 'bounty-recovery-initiative', 'untagged-wallet-exploit']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$4.5M', 'hack_date': '2024-03-07', 'hacked_app_name': 'Credix', 'hacked_app_website': None, 'vuln_contract': '0x0cc3520951a2b41281dcc9a0d37ef3f7f139b75675d83ae72e3b8e903334f35e', 'attacker_addr': '0xF321683831Be16eeD74dfA58b02a37483cEC662e', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['admin-key-compromise', 'privilege-escalation', 'unbacked-token-minting', 'liquidity-drain', 'cross-chain-bridge', 'phantom-collateral-loan', 'multisig-vulnerability', 'insider-threat']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'Access Control', 'total_value_extracted': '$550,000', 'hack_date': '2024-08-13', 'hacked_app_name': 'Coinbase (0xProject Settler Contract)', 'hacked_app_website': 'https://www.coinbase.com/', 'vuln_contract': '0xProject Settler contract', 'attacker_addr': '0x17f79e70ae89c6e32a9244d3d57b7aa648246468', 'attack_complexity': 'low', 'actor_name': None, 'actor_type': 'individual', 'tags': ['misconfigured-approvals', 'erc-20-exploit', 'mev-bot-drain', 'operational-security-failure', 'permissionless-contract-abuse', 'corporate-wallet-drain', 'defi-mechanics-exploit', 'documented-vulnerability', 'third-party-contract-risk', 'crypto-exchange-vulnerability']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'Re-entrancy', 'total_value_extracted': '$42M', 'hack_date': '2023-07-09', 'hacked_app_name': 'GMX V1', 'hacked_app_website': None, 'vuln_contract': '0x489ee077994b6658eafa855c308275ead8097c4a', 'attacker_addr': '0xDF3340A436c27655bA62F8281565C9925C3a5221', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['cross-contract-reentrancy', 'global-short-manipulation', 'glp-pricing-exploit', 'keeper-interaction-hijack', 'arbitrum-exploit', 'vulnerability-patch-failure', 'aum-calculation-flaw', 'audited-code-exploit']}
# {'proto': 'bnb', 'type': 'exploit', 'exploit_type': 'Compromised Private Key', 'total_value_extracted': '$170K', 'hack_date': '2024-06-20', 'hacked_app_name': 'Hacken', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x2FA1789B009A05921eB64F10B8F0d30684661d2d', 'attack_complexity': 'low', 'actor_name': None, 'actor_type': 'individual', 'tags': ['private-key-compromise', 'bridge-vulnerability', 'token-mint-dump', 'human-error-exploit', 'security-firm-breach', 'reputational-damage', 'market-manipulation', 'cross-chain-exploit']}
# {'proto': 'btc', 'type': 'exploit', 'exploit_type': 'Liquidity Manipulation', 'total_value_extracted': '$7M, 58.2 BTC', 'hack_date': '2023-08-12', 'hacked_app_name': 'Odin.fun', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': 'Urguz-m32zo-jlld6-pyy4l-z3c24-jv4pt-5fmll-gq2xd-6siiz-oxkao-xae, jeypm-z6t4p-uqshx-dtay4-qgw5d-ca7j5-alviu-fch2d-nmsnc-c4k3k-aae', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': 'group', 'tags': ['amm-price-manipulation', 'worthless-token-pump', 'liquidity-pool-drain', 'internal-math-exploit', 'sleeper-cell-attack', 'coordinated-attack-pattern', 'repeated-security-failures', 'inadequate-compensation-plan', 'lack-security-audits', 'founder-blame-deflection']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'ERC4626 Donation Attack', 'total_value_extracted': '$9.8M', 'hack_date': '2024-06-25', 'hacked_app_name': 'ResupplyFi', 'hacked_app_website': None, 'vuln_contract': '0x6e90c85a495d54c6d7e1f3400fef1f6e59f86bd6', 'attacker_addr': '0x6D9f6E900ac2CE6770Fd9f04f98B7B0fc355E2EA', 'attack_complexity': 'medium', 'actor_name': None, 'actor_type': 'individual', 'tags': ['erc4626-donation-attack', 'empty-vault-exploit', 'exchange-rate-manipulation', 'low-liquidity-market', 'price-oracle-rounding-bug', 'protocol-economic-exploit', 'unprotected-vault-deployment', 'smart-contract-vulnerability']}
# {'proto': 'btc', 'type': 'exploit', 'exploit_type': 'Weak Cryptographic Key Generation', 'total_value_extracted': '$3.5 billion (initial), $14.8 billion (2025)', 'hack_date': '2020-12-28', 'hacked_app_name': 'LuBian Mining Pool', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': None, 'attack_complexity': 'low', 'actor_name': None, 'actor_type': None, 'tags': ['weak-entropy-exploit', 'bitcoin-private-key', 'mining-pool-hack', 'brute-force-attack', 'undetected-theft', 'long-term-dormant', 'poor-security-practice', 'supply-chain-risk']}
# {'proto': 'eth', 'type': 'exploit', 'exploit_type': 'phishing-attack', 'total_value_extracted': '$14M', 'hack_date': '2024-07-24', 'hacked_app_name': 'WOO X', 'hacked_app_website': None, 'vuln_contract': None, 'attacker_addr': '0x87aab7bac1308fAF2A0d59DA26b8379e18b26355', 'attack_complexity': 'high', 'actor_name': None, 'actor_type': None, 'tags': ['phishing-attack', 'hot-wallet-compromise', 'development-environment-breach', 'multi-chain-exploit', 'targeted-attack', 'insider-threat', 'opsec-failure', 'exchange-breach', 'api-key-compromise', 'supply-chain-attack']}

# %%
newincidents = [json.loads(incident["text"]) for incident in classified_incidents]
with open(
    f"../data/incidents-dataset-20250906-classified-new{'-part' if not status else ''}.json",
    "w",
) as f:
    json.dump(newincidents, f, indent=2)
